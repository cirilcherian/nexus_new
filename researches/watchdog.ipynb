# %%
import pymongo
from bson.json_util import dumps
collection = client["langchain_db"]["langchain_col"]
change_stream = collection.watch()
for change in change_stream:
    print(change)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 collection = client["langchain_db"]["langchain_col"]
#       5 change_stream = collection.watch()
# ----> 6 for change in change_stream:
#       7     print(change)
#
# File c:\Users\ADMIN\anaconda3\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\ADMIN\anaconda3\Lib\site-packages\pymongo\change_stream.py:313, in ChangeStream.next(self)
#     281 """Advance the cursor.
#     282
#     283 This method blocks until the next change document is returned or an
#    (...)
#     310 Raises :exc:`StopIteration` if this ChangeStream is closed.
#     311 """
#     312 while self.alive:
# ...
